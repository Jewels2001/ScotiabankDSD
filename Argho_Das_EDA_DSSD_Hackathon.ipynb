# %% [markdown]
# To display the top 5 rows

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
excel_file_path = '/content/Data.xlsx'
df = pd.read_excel(excel_file_path)
df.head()
# Out:
#    Review_ID                Date  Rating Review_Language   Version  \
# 0          0 2022-04-20 11:38:29       1              en   20.37.2
# 1          1 2023-03-25 19:10:42       5              en   20.47.0
# 2          2 2022-05-31 00:54:40       1              en   20.38.1
# 3          3 2021-06-18 13:16:44       5              en   20.27.0
# 4          4 2023-11-29 13:54:17       1              en  2310.0.1
#
#    Review_Likes                                             Review
# 0             0  Worst bank on the planet. Liars, cheats, and t...
# 1             0                                      App is great.
# 2             0  Barely works. Barely. Stopped giving out notif...
# 3             0                      Really easy for a technophobe
# 4             0                                              Sucks

# %% [markdown]
# To display the top 5 rows

# %%
df.tail(5)
# Out:
#       Review_ID                Date  Rating Review_Language  Version  \
# 9171       9171 2021-04-20 10:16:28       5              en  20.25.1
# 9172       9172 2023-03-05 10:27:12       5              en  20.47.0
# 9173       9173 2023-03-14 15:28:08       5              en  20.47.0
# 9174       9174 2022-10-08 15:08:03       1              en      NaN
# 9175       9175 2021-03-06 18:13:24       4              en  20.24.0
#
#       Review_Likes                                             Review
# 9171             0                            Great app. Easy to use!
# 9172             0                     Great App Top Notch Top Notch!
# 9173             0                       It works like this to should
# 9174             0  This bank insists on barriers that prevents di...
# 9175             0                                    Very convenient

# %% [markdown]
# Checking the basic informaton of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9176 entries, 0 to 9175
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Review_ID        9176 non-null   int64
#  1   Date             9176 non-null   datetime64[ns]
#  2   Rating           9176 non-null   int64
#  3   Review_Language  9176 non-null   object
#  4   Version          8483 non-null   object
#  5   Review_Likes     9176 non-null   int64
#  6   Review           9176 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 501.9+ KB

# %% [markdown]
# Descriptive statistics of the Dataset

# %%
df.describe()
# Out:
#          Review_ID       Rating  Review_Likes
# count  9176.000000  9176.000000   9176.000000
# mean   4587.500000     3.222646      1.042829
# std    2649.027369     1.795973      7.187911
# min       0.000000     1.000000      0.000000
# 25%    2293.750000     1.000000      0.000000
# 50%    4587.500000     4.000000      0.000000
# 75%    6881.250000     5.000000      0.000000
# max    9175.000000     5.000000    236.000000

# %% [markdown]
# Checking for duplicates in the Dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Unique values in Review Language

# %%
df['Review_Language'].unique()
# Out:
# array(['en'], dtype=object)

# %% [markdown]
# Unique values in Version

# %%
df['Version'].unique()
# Out:
# array(['20.37.2', '20.47.0', '20.38.1', '20.27.0', '2310.0.1', '20.30.1',
#        '20.37.1', '20.21.1', '2311.0.1', '20.48.0', '2311.0.0',
#        '2309.0.0', nan, '20.43.0', '20.34.3', '20.26.0', '20.24.0',
#        '2305.0.0', '20.36.0', '20.25.1', '20.28.0', '20.32.0', '20.39.1',
#        '20.41.0', '20.23.0', '20.36.2', '20.34.1', '20.42.1', '20.44.2',
#        '20.36.1', '20.35.0', '20.45.1', '20.34.4', '20.46.1', '20.29.0',
#        '20.40.1', '20.31.1', '20.44.4', '20.33.2', '20.39.0', '2306.0.1',
#        '2305.1.0', '20.38.0', '20.43.2', '20.46.2', '2308.0.0',
#        '2307.0.0', '20.49.1', '2307.0.1', '20.19.0', '20.4.0', '20.15.2',
#        '20.20.2', '20.44.3', '2306.0.2', '20.45.0', '20.11.1', '20.49.2',
#        '20.11.3', '20.31.0', '20.2.00', '20.0.3', '20.44.1', '20.9.2',
#        '20.33.0', '20.16.1', '20.15.1', '20.14.0', '20.25.0', '20.6.2',
#        '20.43.1', '20.1.20', '20.13.1', '20.20.1', '20.11.2', '20.18.0',
# ...

# %% [markdown]
# Unique values in Review Likes

# %%
df['Review_Likes'].unique()
# Out:
# array([  0,   1,   3,   2,   8,  52,   5,  38,  88,   4,  11,   6,  13,
#         31,  87, 148,   9,   7,  65,  19,  21,  12,  24,  39,  18,  10,
#         51,  15,  67,  30,  22,  26,  73,  14, 121,  17,  35,  23,  63,
#         45,  27,  54,  29,  44,  47,  16,  40, 104, 236,  28,  68,  57,
#         20,  60,  25,  48,  34,  81,  43,  79,  58,  55,  61,  41,  92,
#        224,  62,  36,  66,  83, 229,  90,  94, 145,  80])

# %% [markdown]
# Looking for NULL Values

# %%
df.isnull().sum()
# Out:
# Review_ID            0
# Date                 0
# Rating               0
# Review_Language      0
# Version            693
# Review_Likes         0
# Review               0
# dtype: int64

# %% [markdown]
# Replace null values

# %%
df.replace(np.nan,'0',inplace = True)
df.isnull().sum()
# Out:
# Review_ID          0
# Date               0
# Rating             0
# Review_Language    0
# Version            0
# Review_Likes       0
# Review             0
# dtype: int64

# %% [markdown]
# Correlation in Dataset

# %%
df.corr()
# Out:
# <ipython-input-14-2431da76a0dd>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               Review_ID    Rating  Review_Likes
# Review_ID      1.000000  0.001123      0.012917
# Rating         0.001123  1.000000     -0.140182
# Review_Likes   0.012917 -0.140182      1.000000

# %% [markdown]
# Heatmap of the Dataset

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-15-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# Filtering different values in Rating to understand the Dataset

# %%
df[df['Rating']==1].head()
# Out:
#     Review_ID                Date  Rating Review_Language   Version  \
# 0           0 2022-04-20 11:38:29       1              en   20.37.2
# 2           2 2022-05-31 00:54:40       1              en   20.38.1
# 4           4 2023-11-29 13:54:17       1              en  2310.0.1
# 6           6 2022-04-09 11:49:39       1              en   20.37.1
# 10         10 2021-01-04 05:21:00       1              en   20.21.1
#
#     Review_Likes                                             Review
# 0              0  Worst bank on the planet. Liars, cheats, and t...
# 2              0  Barely works. Barely. Stopped giving out notif...
# 4              0                                              Sucks
# 6              0  The cheque deposit is literally the worst. It ...
# 10             0                                    THIS IS TERABLE

# %%
df[df['Rating']==2].head()
# Out:
#     Review_ID                Date  Rating Review_Language   Version  \
# 13         13 2023-09-29 05:51:22       2              en  2309.0.0
# 16         16 2022-10-10 17:42:45       2              en   20.43.0
# 29         29 2021-05-01 10:09:08       2              en   20.25.1
# 39         39 2023-12-14 21:33:28       2              en  2311.0.0
# 43         43 2023-10-04 15:44:22       2              en  2309.0.0
#
#     Review_Likes                                             Review
# 13             0          it does not update the balance right away
# 16             0  It'd be faster to switch banks then to load in...
# 29             0         Because do stuff on thing take days to fix
# 39             0                                     lots of errors
# 43             3  Cheque deposit works now. The recent problem i...

# %%
df[df['Rating']==3].head()
# Out:
#     Review_ID                Date  Rating Review_Language  Version  \
# 14         14 2021-01-24 16:05:46       3              en  20.21.1
# 24         24 2022-01-07 09:25:22       3              en  20.34.3
# 44         44 2022-03-28 03:25:16       3              en  20.36.2
# 58         58 2023-03-18 13:32:21       3              en        0
# 96         96 2023-01-20 21:49:15       3              en  20.45.1
#
#     Review_Likes                                             Review
# 14             0                                Needs to be improve
# 24             1  Like many others, I can't get the cheque depos...
# 44             2  I can't transfer money between my accounts on ...
# 58             0            Where is on my screen on this phone s22
# 96             0  Good sometimes at night it's hard to get onto ...

# %%
df[df['Rating']==4].head()
# Out:
#     Review_ID                Date  Rating Review_Language   Version  \
# 22         22 2023-12-27 17:36:00       4              en  2311.0.1
# 25         25 2022-03-05 17:03:24       4              en   20.36.0
# 34         34 2021-11-15 10:49:54       4              en   20.32.0
# 41         41 2023-03-23 12:53:22       4              en   20.47.0
# 74         74 2021-11-18 12:13:53       4              en   20.31.1
#
#     Review_Likes                                             Review
# 22             0  I have been using this app for almost a year n...
# 25             0                                          Excellent
# 34             0  Good value for the price thought that the brea...
# 41             0  Older hotel, down town location which was inco...
# 74             0                                    I like this app

# %%
df[df['Rating']==5].head()
# Out:
#    Review_ID                Date  Rating Review_Language   Version  \
# 1          1 2023-03-25 19:10:42       5              en   20.47.0
# 3          3 2021-06-18 13:16:44       5              en   20.27.0
# 5          5 2021-09-19 12:32:37       5              en   20.30.1
# 7          7 2021-01-29 20:58:49       5              en   20.21.1
# 8          8 2024-01-18 07:36:55       5              en  2311.0.1
#
#    Review_Likes                                             Review
# 1             0                                      App is great.
# 3             0                      Really easy for a technophobe
# 5             0  Now I can use my fingerprints to log on, just ...
# 7             0                                                Yup
# 8             0             Wonderful! Service good, Bonuses nice!
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %% [markdown]
# Checking the distribution for "Rating" values across all reviews

# %%
rating_mean = df['Rating'].mean()
rating_mode = df['Rating'].mode()
rating_median = df['Rating'].median()
rating_std = df['Rating'].std()

print("The mean rating is: ", rating_mean)
print("The most common rating is: ", rating_mode)
print("The median rating is: ", rating_median)
print("The standard deviation of the rating is: ", rating_std)
sns.countplot(df, x='Rating')
plt.axvline(rating_mean, color="red")
plt.axvline(rating_median, color="orange")
# Out:
# The mean rating is:  3.2226460331299043
# The most common rating is:  0    5
# Name: Rating, dtype: int64
# The median rating is:  4.0
# The standard deviation of the rating is:  1.7959729143050105

# %% [markdown]
# Tokenized the dataset in 1 word (Frequency)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')

excel_file_path = '/content/Data.xlsx'
df = pd.read_excel(excel_file_path)

text_column_name = 'Review'

text_data = ' '.join(df[text_column_name].astype(str))

translator = str.maketrans('', '', string.punctuation)
text_data_no_punct = text_data.translate(translator)
tokens = word_tokenize(text_data_no_punct)

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

fdist = FreqDist(filtered_tokens)

fdist.plot(20, cumulative=False)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Tokenized the dataset in 2 word (Frequency)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string
from nltk import ngrams
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')

excel_file_path = '/content/Data.xlsx'
df = pd.read_excel(excel_file_path)

text_column_name = 'Review'

text_data = ' '.join(df[text_column_name].astype(str))

translator = str.maketrans('', '', string.punctuation)
text_data_no_punct = text_data.translate(translator)

tokens = ngrams(word_tokenize(text_data_no_punct), 2)

trigrams = [' '.join(token) for token in tokens]

stop_words = set(stopwords.words('english'))
filtered_trigrams = [trigram for trigram in trigrams if all(word.lower() not in stop_words for word in trigram.split())]

fdist = FreqDist(filtered_trigrams)

fdist.plot(20, cumulative=False)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Tokenized the dataset in 3 word (Frequency)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string
from nltk import ngrams
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')

excel_file_path = '/content/Data.xlsx'
df = pd.read_excel(excel_file_path)

text_column_name = 'Review'

text_data = ' '.join(df[text_column_name].astype(str))

translator = str.maketrans('', '', string.punctuation)
text_data_no_punct = text_data.translate(translator)

tokens = ngrams(word_tokenize(text_data_no_punct), 3)

trigrams = [' '.join(token) for token in tokens]

stop_words = set(stopwords.words('english'))
filtered_trigrams = [trigram for trigram in trigrams if all(word.lower() not in stop_words for word in trigram.split())]

fdist = FreqDist(filtered_trigrams)

fdist.plot(20, cumulative=False)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Tokenized the dataset in 4 word (Frequency)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string
from nltk import ngrams
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')

excel_file_path = '/content/Data.xlsx'
df = pd.read_excel(excel_file_path)

text_column_name = 'Review'

text_data = ' '.join(df[text_column_name].astype(str))

translator = str.maketrans('', '', string.punctuation)
text_data_no_punct = text_data.translate(translator)

tokens = ngrams(word_tokenize(text_data_no_punct), 4)

trigrams = [' '.join(token) for token in tokens]

stop_words = set(stopwords.words('english'))
filtered_trigrams = [trigram for trigram in trigrams if all(word.lower() not in stop_words for word in trigram.split())]

fdist = FreqDist(filtered_trigrams)

fdist.plot(20, cumulative=False)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Tokenized the dataset in 5 word (Frequency)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string
from nltk import ngrams
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')

excel_file_path = '/content/Data.xlsx'
df = pd.read_excel(excel_file_path)

text_column_name = 'Review'

text_data = ' '.join(df[text_column_name].astype(str))

translator = str.maketrans('', '', string.punctuation)
text_data_no_punct = text_data.translate(translator)

tokens = ngrams(word_tokenize(text_data_no_punct), 5)

trigrams = [' '.join(token) for token in tokens]

stop_words = set(stopwords.words('english'))
filtered_trigrams = [trigram for trigram in trigrams if all(word.lower() not in stop_words for word in trigram.split())]

fdist = FreqDist(filtered_trigrams)

fdist.plot(20, cumulative=False)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Tokenized the dataset [All Lowercase] in 5 word (Frequency)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string
from nltk import ngrams
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')

excel_file_path = '/content/Data.xlsx'
df = pd.read_excel(excel_file_path)

df['Review'] = df['Review'].astype(str).str.lower()

text_data = ' '.join(df['Review'])

translator = str.maketrans('', '', string.punctuation)
text_data_no_punct = text_data.translate(translator)

# Tokenize into trigrams
tokens = ngrams(word_tokenize(text_data_no_punct), 5)

# Convert trigrams to a list of strings
trigrams = [' '.join(token) for token in tokens]

# Remove stopwords from trigrams
stop_words = set(stopwords.words('english'))
filtered_trigrams = [trigram for trigram in trigrams if all(word.lower() not in stop_words for word in trigram.split())]

fdist = FreqDist(filtered_trigrams)

fdist.plot(20, cumulative=False)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Sentiment Analysis (Clasifying all Reviews as either Positive, Negative or Neutral)

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd

# Download the VADER lexicon if not already present
nltk.download('vader_lexicon')

def analyze_sentiment(sentence):
    sid = SentimentIntensityAnalyzer()
    sentiment_scores = sid.polarity_scores(sentence)

    if sentiment_scores['compound'] >= 0.05:
        return 'Positive'
    elif sentiment_scores['compound'] <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

output_file_path = '/content/Data.xlsx'
df = pd.read_excel(output_file_path)

column_to_analyze = 'Review'
df['Sentiment'] = df[column_to_analyze].apply(analyze_sentiment)

output_file_path = 'output_with_sentiment.xlsx'
df.to_excel(output_file_path, index=False)

print(f'Sentiment analysis completed. Results saved to {output_file_path}')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Sentiment analysis completed. Results saved to output_with_sentiment.xlsx

# %% [markdown]
# Detecting Outliers in Version

# %%
sns.boxplot(x=df['Version'])
# Out:
# <Axes: xlabel='Version'>

# %% [markdown]
# Printing the IQR

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Review_ID       4587.5
# Rating             4.0
# Review_Likes       0.0
# dtype: float64
# <ipython-input-24-d7397e803310>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# <ipython-input-24-d7397e803310>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)
