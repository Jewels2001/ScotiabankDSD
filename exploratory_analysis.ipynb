# %%
# !pip install seaborn
# !pip install pandas
# !pip install openpyxl
# Out:
# ...
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_excel("Data/Data.xlsx")
df.head()
# Out:
#    Review_ID                Date  Rating Review_Language   Version  \
# 0          0 2022-04-20 11:38:29       1              en   20.37.2
# 1          1 2023-03-25 19:10:42       5              en   20.47.0
# 2          2 2022-05-31 00:54:40       1              en   20.38.1
# 3          3 2021-06-18 13:16:44       5              en   20.27.0
# 4          4 2023-11-29 13:54:17       1              en  2310.0.1
#
#    Review_Likes                                             Review
# 0             0  Worst bank on the planet. Liars, cheats, and t...
# 1             0                                      App is great.
# 2             0  Barely works. Barely. Stopped giving out notif...
# 3             0                      Really easy for a technophobe
# 4             0                                              Sucks

# %%
df.dtypes
# Out:
# Review_ID                   int64
# Date               datetime64[ns]
# Rating                      int64
# Review_Language            object
# Version                    object
# Review_Likes                int64
# Review                     object
# dtype: object

# %% [markdown]
# ## Summary Statistics

# %%
rating_mean = df['Rating'].mean()
rating_mode = df['Rating'].mode()
rating_median = df['Rating'].median()
rating_std = df['Rating'].std()

print("The mean rating is: ", rating_mean)
print("The most common rating is: ", rating_mode)
print("The median rating is: ", rating_median)
print("The standard deviation of the rating is: ", rating_std)
# Out:
# The mean rating is:  3.2226460331299043
# The most common rating is:  0    5
# Name: Rating, dtype: int64
# The median rating is:  4.0
# The standard deviation of the rating is:  1.7959729143050105

# %%
sns.countplot(df, x='Rating')
plt.axvline(rating_mean, color="red")
plt.axvline(rating_median, color="orange")

# %%
sns.scatterplot(data=df, x='Date', y='Version').set(xlabel='Date of Review', ylabel='Version')
# Out:
# [Text(0.5, 0, 'Date of Review'), Text(0, 0.5, 'Version')]

# %%
sns.countplot(df, x='Review_Likes', width=1, stat='probability')
# Out:
# <Axes: xlabel='Review_Likes', ylabel='probability'>

# %%
sns.countplot(df, x='Review_Likes', width=1, stat='count')
# Out:
# <Axes: xlabel='Review_Likes', ylabel='count'>

# %%
df.count()
# Out:
# Review_ID          9176
# Date               9176
# Rating             9176
# Review_Language    9176
# Version            8483
# Review_Likes       9176
# Review             9176
# dtype: int64
